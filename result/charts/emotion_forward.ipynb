# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

data = [783898, 2012527, 423090]

# %%
labels = 'Ambivalent', 'Positive', 'Negative'
colors = ['yellowgreen', 'lightskyblue', 'orange']
explode = [0.1, 0.1, 0.1]

plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%',
        startangle=90, explode=explode, shadow=False)
plt.axis('equal')

plt.savefig('emotion_forward.png', dpi = 600)
