# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

data = {} # key: HH:MM -> {'0':, '1':, '2':, '-2':, '-1':}
with open('../emotion_time.txt', 'r') as f:
    for line in f:
        l = line.split()
        time_label = l[0]
        count = int(l[1])
        
        l = time_label.split(':')
        t = l[0] + ':' + l[1]
        label = int(l[2])
        
        d = data.get(t, [0] * 5)
        d[label] = count
        data[t] = d

moments = sorted(data)
num_tweets_m = [sum(data[t]) for t in moments]

N = 24
n = len(num_tweets_m) / N
num_tweets = [sum(num_tweets_m[i * n: (i+1) * n]) for i in range(N)]

# %%
plt.plot(num_tweets)
plt.xlim([0, 23])
# Out:
# (0, 23)

# %%
ind = np.arange(N)    # the x locations for the groups
np_num_tweets = np.array(num_tweets)

p1 = plt.bar(ind, num_tweets, color='b', alpha=0.4)

plt.ylabel('Count')
plt.xlabel('Time(h)')
plt.title('#Weibo - time')

plt.plot(num_tweets, 'b--', alpha=0.3)
plt.xlim([0, 24])
plt.savefig('weibo_time.png', dpi = 600)
